# %% [markdown]
# ## 딥러닝
#
# ### 심층신경망

# %%
# 모듈 로드
import tensorflow as tf
from tensorflow import keras
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Source\IoT_DataAnalysis_2025\mlvenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# - 이미 이전장에서 다운로드 했기때문에 다시 다운로드 하지 않음

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
train_input = train_input.reshape(-1, 28*28)
test_input = test_input.reshape(-1, 28*28)

# %%
# 스케일링
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train_input.astype(np.float64))
test_scaled = scaler.transform(test_input.astype(np.float64))

# %%
# 훈련세트, 검증세트 분리
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
print(train_scaled.shape, val_scaled.shape, test_scaled.shape)
print(train_target.shape, val_target.shape, test_target.shape)
# Out:
# (48000, 784) (12000, 784) (10000, 784)
# (48000,) (12000,) (10000,)

# %% [markdown]
# ##### 심층신경망 만들기1

# %%
# 밀집층 생성
dense1 = keras.layers.Dense(100, activation='sigmoid', input_shape=(784,), name='hidden')
dense2 = keras.layers.Dense(10, activation='softmax', name='output')

# %%
# 신경망 모델 생성
model = keras.Sequential([dense1, dense2])
# Out:
# WARNING:tensorflow:From c:\Source\IoT_DataAnalysis_2025\mlvenv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# 모델 요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### 심층신경망 만들기2

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='sigmoid', input_shape=(784,), name='hidden'),
    keras.layers.Dense(10, activation='softmax', name='output')
], name='Fashion_MNIST_Model')

# %%
model.summary()
# Out:
# Model: "Fashion_MNIST_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 훈련전 설정
model.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')
# Out:
# WARNING:tensorflow:From c:\Source\IoT_DataAnalysis_2025\mlvenv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 훈련
model.fit(train_scaled, train_target, epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Source\IoT_DataAnalysis_2025\mlvenv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Source\IoT_DataAnalysis_2025\mlvenv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.4672 - accuracy: 0.8386
# Epoch 2/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3544 - accuracy: 0.8741
# Epoch 3/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3184 - accuracy: 0.8857
# Epoch 4/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2941 - accuracy: 0.8947
# Epoch 5/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2732 - accuracy: 0.9019
# Epoch 6/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2565 - accuracy: 0.9084
# Epoch 7/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2434 - accuracy: 0.9133
# Epoch 8/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2285 - accuracy: 0.9195
# Epoch 9/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2163 - accuracy: 0.9233
# Epoch 10/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2057 - accuracy: 0.9268
# Epoch 11/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1952 - accuracy: 0.9311
# Epoch 12/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1855 - accuracy: 0.9351
# Epoch 13/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1768 - accuracy: 0.9382
# Epoch 14/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1678 - accuracy: 0.9419
# Epoch 15/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1599 - accuracy: 0.9450
# Epoch 16/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1525 - accuracy: 0.9481
# Epoch 17/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1442 - accuracy: 0.9509
# Epoch 18/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1384 - accuracy: 0.9524
# Epoch 19/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1321 - accuracy: 0.9549
# Epoch 20/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1254 - accuracy: 0.9582
# Epoch 21/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1188 - accuracy: 0.9605
# Epoch 22/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1130 - accuracy: 0.9628
# Epoch 23/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1082 - accuracy: 0.9649
# Epoch 24/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1025 - accuracy: 0.9665
# Epoch 25/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0985 - accuracy: 0.9679
# Epoch 26/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0932 - accuracy: 0.9702
# Epoch 27/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0883 - accuracy: 0.9724
# Epoch 28/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0834 - accuracy: 0.9739
# Epoch 29/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0792 - accuracy: 0.9758
# Epoch 30/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0758 - accuracy: 0.9762
# Epoch 31/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0724 - accuracy: 0.9779
# Epoch 32/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0690 - accuracy: 0.9780
# Epoch 33/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0654 - accuracy: 0.9794
# Epoch 34/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0618 - accuracy: 0.9819
# Epoch 35/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0595 - accuracy: 0.9825
# Epoch 36/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0565 - accuracy: 0.9832
# Epoch 37/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0545 - accuracy: 0.9842
# Epoch 38/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0508 - accuracy: 0.9851
# Epoch 39/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0490 - accuracy: 0.9853
# Epoch 40/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0463 - accuracy: 0.9866
# Epoch 41/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0441 - accuracy: 0.9875
# Epoch 42/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0429 - accuracy: 0.9874
# Epoch 43/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0407 - accuracy: 0.9888
# Epoch 44/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0383 - accuracy: 0.9895
# Epoch 45/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0367 - accuracy: 0.9897
# Epoch 46/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0353 - accuracy: 0.9900
# Epoch 47/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0337 - accuracy: 0.9909
# Epoch 48/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0318 - accuracy: 0.9912
# Epoch 49/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0298 - accuracy: 0.9920
# Epoch 50/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0290 - accuracy: 0.9918
# Epoch 51/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0274 - accuracy: 0.9924
# Epoch 52/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0268 - accuracy: 0.9929
# Epoch 53/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0249 - accuracy: 0.9935
# Epoch 54/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0235 - accuracy: 0.9936
# Epoch 55/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0219 - accuracy: 0.9941
# Epoch 56/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0211 - accuracy: 0.9945
# Epoch 57/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0200 - accuracy: 0.9949
# Epoch 58/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0197 - accuracy: 0.9945
# Epoch 59/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0182 - accuracy: 0.9952
# Epoch 60/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0175 - accuracy: 0.9954
# Epoch 61/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0166 - accuracy: 0.9956
# Epoch 62/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0158 - accuracy: 0.9960
# Epoch 63/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0150 - accuracy: 0.9960
# Epoch 64/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0139 - accuracy: 0.9964
# Epoch 65/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0135 - accuracy: 0.9966
# Epoch 66/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0127 - accuracy: 0.9970
# Epoch 67/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0117 - accuracy: 0.9973
# Epoch 68/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0112 - accuracy: 0.9975
# Epoch 69/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0108 - accuracy: 0.9974
# Epoch 70/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0108 - accuracy: 0.9976
# Epoch 71/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0089 - accuracy: 0.9980
# Epoch 72/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0092 - accuracy: 0.9982
# Epoch 73/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0085 - accuracy: 0.9981
# Epoch 74/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0080 - accuracy: 0.9983
# Epoch 75/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0068 - accuracy: 0.9986
# Epoch 76/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0073 - accuracy: 0.9984
# Epoch 77/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0067 - accuracy: 0.9984
# Epoch 78/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0067 - accuracy: 0.9984
# Epoch 79/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0059 - accuracy: 0.9988
# Epoch 80/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 81/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0056 - accuracy: 0.9987
# Epoch 82/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0045 - accuracy: 0.9991
# Epoch 83/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0045 - accuracy: 0.9989
# Epoch 84/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0040 - accuracy: 0.9992
# Epoch 85/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0039 - accuracy: 0.9993
# Epoch 86/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0029 - accuracy: 0.9995
# Epoch 87/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 88/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0025 - accuracy: 0.9996
# Epoch 89/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 90/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 91/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0021 - accuracy: 0.9997
# Epoch 92/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0019 - accuracy: 0.9997
# Epoch 93/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0018 - accuracy: 0.9997
# Epoch 94/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 95/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 96/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 9.3714e-04 - accuracy: 0.9999
# Epoch 97/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 9.8471e-04 - accuracy: 0.9999
# Epoch 98/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 8.4998e-04 - accuracy: 0.9999
# Epoch 99/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 7.9037e-04 - accuracy: 0.9999
# Epoch 100/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 6.6405e-04 - accuracy: 0.9999

# %%
model.evaluate(val_scaled, val_target)
# 검증 정확도 : 87.8%
# Out:
# 375/375 [==============================] - 0s 937us/step - loss: 0.8446 - accuracy: 0.8780
# [0.8445530533790588, 0.878000020980835]

# %%
pred_result = model.predict(test_scaled)
# Out:
# 313/313 [==============================] - 0s 908us/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# 한글로 Matplotlib 사용시 항상 필요
from matplotlib import rcParams, font_manager, rc

font_path = 'C:/Windows/Fonts/malgun.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
rcParams['axes.unicode_minus'] = False

sns.set_style('darkgrid')
sns.set_theme(font='Malgun Gothic', rc={'axes.unicode_minus': False})

# %%
class_names = ['티셔츠', '바지', '스웨터', '드레스', '코트', '샌달', '셔츠', '스니커즈', '가방', '앵클부츠']

# %%
# 테스트이미지와 예측결과 시각화
def show_image(index):
    plt.figure(figsize=(2,2))
    plt.imshow(test_input[index].reshape(28, 28), cmap='gray_r')
    true_label = class_names[test_target[index]]
    pred_label = class_names[np.argmax(pred_result[index])]

    #plt.title(f'실제: {true_label}, 예측: {pred_label}')
    plt.text(0, -6, f'실제: {true_label}', fontsize=12, color='blue')
    plt.text(0, -3, f'예측: {pred_label}', fontsize=12, color='red', fontweight='bold')

    plt.axis('off')
    plt.show()

# %%
for i in range(10,13):
    show_image(i)

# %% [markdown]
# #### 렐루 함수
#
# - 인공신경망 은닉층에 초기에는 Sigmoid 함수 사용
#     - 단점 : 오른쪽, 왼쪽 끝으로 갈 수록 그래프가 누워있어서 올바른 출력을 못만듬
#
# - 렐루함수(ReLU) : 수정된 선형유닛 뜻의 함수
#
#     <img src="../image/ml0011.png" width="500">

# %% [markdown]
# #### Flatten 객체
# - 이미지 2차원배열을 1차원으로 변경할때 np.reshape() 사용
# - Flatten 클래스가 위의 일을 대신해줌

# %%
model2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28), name='flatten'),
    keras.layers.Dense(100, activation='relu', name='hidden'),
    keras.layers.Dense(10, activation='softmax', name='output')
], name='Fashion_MNIST_RELU')

# %%
model2.summary()
# Out:
# Model: "Fashion_MNIST_RELU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

# %%
train_scaled = train_input / 255.0
test_scaled = test_input / 255.0

# %%
# 훈련세트, 검증세트 분리
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
# 모델 설정
model2.compile(loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
# 모델 훈련
model2.fit(train_scaled, train_target, epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5285 - accuracy: 0.8138
# Epoch 2/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3921 - accuracy: 0.8600
# Epoch 3/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3556 - accuracy: 0.8722
# Epoch 4/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3339 - accuracy: 0.8800
# Epoch 5/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3185 - accuracy: 0.8852
# Epoch 6/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3069 - accuracy: 0.8911
# Epoch 7/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2977 - accuracy: 0.8950
# Epoch 8/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2878 - accuracy: 0.8971
# Epoch 9/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2807 - accuracy: 0.9000
# Epoch 10/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2749 - accuracy: 0.9041
# Epoch 11/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2662 - accuracy: 0.9066
# Epoch 12/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2615 - accuracy: 0.9086
# Epoch 13/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2559 - accuracy: 0.9106
# Epoch 14/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2520 - accuracy: 0.9131
# Epoch 15/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2456 - accuracy: 0.9143
# Epoch 16/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2402 - accuracy: 0.9168
# Epoch 17/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2374 - accuracy: 0.9184
# Epoch 18/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2327 - accuracy: 0.9208
# Epoch 19/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2296 - accuracy: 0.9201
# Epoch 20/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2259 - accuracy: 0.9224

# %%
model2.evaluate(val_scaled, val_target)
# ReLU함수 사용시, Sigmoid함수 사용시 0.01% 개선
# Out:
# 375/375 [==============================] - 0s 965us/step - loss: 0.4511 - accuracy: 0.8788
# [0.45114126801490784, 0.8788333535194397]

# %% [markdown]
# #### 옵티마이저
# - 하이퍼파라미터 값 최적화

# %%
model3 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28), name='flatten'),
    keras.layers.Dense(100, activation='relu', name='hidden'),
    keras.layers.Dense(10, activation='softmax', name='output')
], name='Fashion_MNIST_RELU')

# %%
# 모델3 설정, 최적화는 adam클래스만 사용할 것
model3.compile(loss='sparse_categorical_crossentropy', metrics='accuracy', optimizer='adam')

# %%
# 모델 훈련. 모델훈련은 정보를 저장하기 때문에 다시 수행하면 이전 정보를 담고 시작
model3.fit(train_scaled, train_target, epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5236 - accuracy: 0.8147
# Epoch 2/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3963 - accuracy: 0.8581
# Epoch 3/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3543 - accuracy: 0.8706
# Epoch 4/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3291 - accuracy: 0.8807
# Epoch 5/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3082 - accuracy: 0.8868
# Epoch 6/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2929 - accuracy: 0.8917
# Epoch 7/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2779 - accuracy: 0.8982
# Epoch 8/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2689 - accuracy: 0.9004
# Epoch 9/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2568 - accuracy: 0.9045
# Epoch 10/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2493 - accuracy: 0.9066
# Epoch 11/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2415 - accuracy: 0.9105
# Epoch 12/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2326 - accuracy: 0.9139
# Epoch 13/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2250 - accuracy: 0.9178
# Epoch 14/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2219 - accuracy: 0.9172
# Epoch 15/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2133 - accuracy: 0.9202
# Epoch 16/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2086 - accuracy: 0.9221
# Epoch 17/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2017 - accuracy: 0.9247
# Epoch 18/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1970 - accuracy: 0.9280
# Epoch 19/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1920 - accuracy: 0.9278
# Epoch 20/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1871 - accuracy: 0.9300

# %% [markdown]
# - optimizer 사용시 0.01정도 개선

# %%
model3.evaluate(val_scaled, val_target)
# 훈련 95%, 검증 88% - 7정도 차이
# Out:
# 375/375 [==============================] - 0s 927us/step - loss: 0.3418 - accuracy: 0.8890
# [0.3417823612689972, 0.8889999985694885]

# %% [markdown]
# #### 드롭아웃
# - 훈련과정 밀집층에 일부 뉴런을 꺼버림.

# %%
model4 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28), name='flatten'),
    keras.layers.Dense(100, activation='relu', name='hidden'),
    keras.layers.Dropout(0.3, name='dropout'), 
    keras.layers.Dense(10, activation='softmax', name='output')
], name='Fashion_MNIST_RELU')

# %%
model4.summary()
# Out:
# Model: "Fashion_MNIST_RELU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  hidden (Dense)              (None, 100)               78500
#
#  dropout (Dropout)           (None, 100)               0
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델4 설정, 최적화는 adam클래스만 사용할 것
model4.compile(loss='sparse_categorical_crossentropy', metrics='accuracy', optimizer='adam')

# %%
# 모델 훈련. 모델훈련은 정보를 저장하기 때문에 다시 수행하면 이전 정보를 담고 시작
model4.fit(train_scaled, train_target, epochs=20)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5936 - accuracy: 0.7917
# Epoch 2/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.4412 - accuracy: 0.8408
# Epoch 3/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.4044 - accuracy: 0.8538
# Epoch 4/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3837 - accuracy: 0.8591
# Epoch 5/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3701 - accuracy: 0.8651
# Epoch 6/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3551 - accuracy: 0.8712
# Epoch 7/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3443 - accuracy: 0.8738
# Epoch 8/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3356 - accuracy: 0.8756
# Epoch 9/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3268 - accuracy: 0.8802
# Epoch 10/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3219 - accuracy: 0.8801
# Epoch 11/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3138 - accuracy: 0.8848
# Epoch 12/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3085 - accuracy: 0.8847
# Epoch 13/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3049 - accuracy: 0.8859
# Epoch 14/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2993 - accuracy: 0.8876
# Epoch 15/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2924 - accuracy: 0.8898
# Epoch 16/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2919 - accuracy: 0.8905
# Epoch 17/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2873 - accuracy: 0.8911
# Epoch 18/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2840 - accuracy: 0.8925
# Epoch 19/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2817 - accuracy: 0.8954
# Epoch 20/20
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2779 - accuracy: 0.8952

# %%
model4.evaluate(val_scaled, val_target)
# 훈련 89%, 검증 88% - 1차이(훈련과 검증사이에 차이가 거의 없음)
# Out:
# 375/375 [==============================] - 0s 964us/step - loss: 0.3168 - accuracy: 0.8907
# [0.31683677434921265, 0.890666663646698]

# %% [markdown]
# - 드롭아웃하면 정확도가 떨어짐 > 훈련과 검증(테스트)사이에 정확도 차이가 줄어듬
# - `과대적합`(훈련세트 훈련에 너무 치중하여서 정확도가 너무 높은 것) 방지

# %% [markdown]
# #### 모델의 저장과 복원
# - 훈련시간이 딥러닝에 크게 좌우됨. 저장이 없으면 다시 훈련시키고 시간을 소요해야 됨
# - 파일로 저장 후 모델에 대한 구조와 파라미터 만 저장하는 두가지 방법이 존재

# %%
# 모델4 저장 - 파라미터만 저장
model4.save_weights('./model4-weight.h5')

# %%
# 모델4 저장 - 전체(모델 구조와 파라미터) 저장
model4.save('./model4-whole.h5')
# Out:
# c:\Source\IoT_DataAnalysis_2025\mlvenv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ##### 모델 사용
# - 파라미터만 저장한 파일을 사용하려면, 먼저 모델을 생성해야

# %%
model5 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28), name='flatten5'),
    keras.layers.Dense(100, activation='relu', name='hidden5'),
    keras.layers.Dropout(0.3, name='dropout5'), 
    keras.layers.Dense(10, activation='softmax', name='output5')
], name='Fashion_MNIST_RELU5')

# %%
model5.load_weights('./model4-weight.h5')

# %%
model5.summary()
# Out:
# Model: "Fashion_MNIST_RELU5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten5 (Flatten)          (None, 784)               0
#
#  hidden5 (Dense)             (None, 100)               78500
#
#  dropout5 (Dropout)          (None, 100)               0
#
#  output5 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
pred_result = model5.predict(test_scaled)
# Out:
# 313/313 [==============================] - 0s 927us/step

# %% [markdown]
# - 모델까지 전부 생성해주는 방법

# %%
model6 = keras.models.load_model('./model4-whole.h5')

# %%
model6.summary()
# Out:
# Model: "Fashion_MNIST_RELU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  hidden (Dense)              (None, 100)               78500
#
#  dropout (Dropout)           (None, 100)               0
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79510 (310.59 KB)
# Trainable params: 79510 (310.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model6.evaluate(test_scaled, test_target)
# Out:
# 313/313 [==============================] - 0s 970us/step - loss: 0.3493 - accuracy: 0.8798
# [0.34929192066192627, 0.879800021648407]

# %% [markdown]
# #### 콜백
# - 실행도중 다른 일을 할 수 있도록 해주는 기능
# - `조기종료`를 위해서 사용.

# %%
model7 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28), name='flatten'),
    keras.layers.Dense(100, activation='relu', name='hidden'),
    keras.layers.Dropout(0.3, name='dropout'), 
    keras.layers.Dense(10, activation='softmax', name='output')
], name='Fashion_MNIST_RELU7')

# %%
model7.compile(loss='sparse_categorical_crossentropy', metrics='accuracy', optimizer='adam')

# %%
# 에포크마다 모델 저장기능 콜백
checkpoint_cb = keras.callbacks.ModelCheckpoint('./best-model.h5', save_best_only=True) # 최고 상태면 저장
# 조기종료 콜백
## 두번이상 훈련값이 동일하면 조기종료, 이전 최고상태로 복구
early_stopp_cb = keras.callbacks.EarlyStopping(patience=2, restore_best_weights=True)

# %%
# 모델 훈련. 모델훈련은 정보를 저장하기 때문에 다시 수행하면 이전 정보를 담고 시작
model7.fit(train_scaled, train_target, epochs=20, validation_data=(val_scaled, val_target),
           callbacks=[checkpoint_cb, early_stopp_cb])
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5935 - accuracy: 0.7932 - val_loss: 0.4211 - val_accuracy: 0.8481
# Epoch 2/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4384 - accuracy: 0.8416 - val_loss: 0.3847 - val_accuracy: 0.8613
# Epoch 3/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.4002 - accuracy: 0.8532 - val_loss: 0.3751 - val_accuracy: 0.8599
# Epoch 4/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3781 - accuracy: 0.8620 - val_loss: 0.3553 - val_accuracy: 0.8716
# Epoch 5/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3621 - accuracy: 0.8653 - val_loss: 0.3459 - val_accuracy: 0.8747
# Epoch 6/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3513 - accuracy: 0.8686 - val_loss: 0.3411 - val_accuracy: 0.8759
# Epoch 7/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3437 - accuracy: 0.8737 - val_loss: 0.3338 - val_accuracy: 0.8771
# Epoch 8/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3332 - accuracy: 0.8776 - val_loss: 0.3306 - val_accuracy: 0.8811
# Epoch 9/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3239 - accuracy: 0.8797 - val_loss: 0.3199 - val_accuracy: 0.8836
# Epoch 10/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3172 - accuracy: 0.8829 - val_loss: 0.3165 - val_accuracy: 0.8849
# Epoch 11/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3130 - accuracy: 0.8830 - val_loss: 0.3179 - val_accuracy: 0.8828
# Epoch 12/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3054 - accuracy: 0.8859 - val_loss: 0.3158 - val_accuracy: 0.8861
# Epoch 13/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3019 - accuracy: 0.8885 - val_loss: 0.3148 - val_accuracy: 0.8857
# Epoch 14/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2963 - accuracy: 0.8898 - val_loss: 0.3196 - val_accuracy: 0.8855
# Epoch 15/20
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2911 - accuracy: 0.8919 - val_loss: 0.3239 - val_accuracy: 0.8827

# %%
model7.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 0s 1ms/step - loss: 0.3148 - accuracy: 0.8857
# [0.31480708718299866, 0.8857499957084656]

# %%
model7.evaluate(test_scaled, test_target)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3439 - accuracy: 0.8798
# [0.3439006209373474, 0.879800021648407]

# %%
early_stopp_cb.stopped_epoch
# Out:
# 14

# %% [markdown]
# - 20번중 15번반복에서 조기종료

# %% [markdown]
# #### 결론
# - `심층 신경망` : 2개 이상의 밀집층을 포함한 신경망 모델. 다층 인공신경망
# - `렐루함수` : 시그모이드 함수의 단점을 보완한 활성화 함수
# - `옵티마이저` : 신경망의 가중치(기울기)와 절편을 학습하기 위한 알고리즘 또는 방법. `Adam`, SGD(확률적 경사하강법), RMSprop...
#
# - `드롭아웃` : 밀집층의 뉴런을 임의로 꺼서 훈련을 덜 시키는 것. 과대적합 막기위해서 수행
# - 모델 저장과 복원 : 이미 훈련된 데이터를 저장했다가 나중에 다시 쓰기 위해서
# - `콜백` : 에포크마다 모델 저장 또는 조기종료 를 위해서 훈련 도중에 다른 기능을 수행하는 것
